# %% [markdown]
# # Big O Notation Exercise
#
#
#
# Title your chart "Big O Notation"
# Label your x axis "Elements"
# Label your y axis "Operations"
# Label your curves or make a legend for the curves
# Use LaTex notation where possible

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
x = list(np.arange(1,50, 0.1))

plt.figure(figsize=(15, 10)) # (width, height)

def n_plus_one(x):
    return n + 1

def log_n(x):
    return np.log(n)

def n(x):
    return x ** 2 - x + 2

def n_log_n(x):
    return x ** 2 - x + 2

def n_squared(x):
    return x ** 2 - x + 2

def two_to_the_nth(x):
    return x ** 2 - x + 2

def n_factorial(x):
    return x ** 2 - x + 2

def n_to_the_nth(x):
    return x ** 2 - x + 2


plt.plot(x,[n + 1 for n in x], 'y', label='$O(1)$')
plt.plot(x, [np.log(n) for n in x], 'g', label='$O(log n)$')
plt.plot(x, [n for n in x] , 'b', label='$O(n)$')
plt.plot(x, [n * (np.log(n)) for n in x], 'r', label='$O(n log n)$')
plt.plot(x,[n ** 2 for n in x], 'orange', label='$O(n^2)$')
plt.plot(x, [2 ** n for n in x], 'purple', label='$O(2^n)$')
plt.plot(x, [math.factorial(int(n)) for n in x] , 'black', label='$O(n!)$')
plt.plot(x, [n ** n  for n in x], 'pink', label='$O(n^n)$')

plt.ylim(top=50, bottom = 0)
plt.legend(loc='upper left')
plt.suptitle('Big O Notation',fontsize=28)
plt.xlabel('Elements')
plt.ylabel('Operations')

#hfont = {'fontname': 'Rockwell'}
hfont = {'fontname': 'Academy Engraved LET'}

plt.title('Veronica F. Reyes', loc='left', fontsize=20, **hfont)


plt.show()

# %% [markdown]
# ### Bonus Write the code necessary to write your name on a chart. Use box letters.

# %% [markdown]
# ### Bonus: use curves for letters in your name that have curves in them.

# %%
#import matplotlib.font_manager
#set([f.name for f in matplotlib.font_manager.fontManager.afmlist]) and set([f.name for f in matplotlib.font_manager.fontManager.ttflist])

# %%
# y = 0n + 1  and label the curve "0(1)"

x = pd.Series(range(1,50))
y = 0 * x + 1

# %%
# y = log(n)

y1 = np.log(x)

# %%
# y = n
y2 = x

# %%
# y = n * log(n)
y3= x * np.log(x)

# %%
y4 = x ** 2
y5 = 2 ** x
# x!
y6 = x.apply(np.math.factorial)
# n ^ n 
y7 = x

# %%
plt.figure(figsize=(15, 10)) # (width, height)

plt.plot(x,y, label="y = $0(n)+1$")
plt.plot(x, y1, label = "$y = log(n)$")
plt.plot(x, y2, label = "$y = n$")
plt.plot(x, y3, label= "$y - n * log(n)$")
plt.plot(x, y4, label = "$y = n ^ 2$")
plt.plot(x, y5, label= "$y = 2 ^n$")
plt.plot(x, y6, label= "$y = n!$")
plt.plot(x, y7, label= "$y = n ^ n$ ")

plt.xlim(0,50)
plt.ylim(0,50)
plt.suptitle("Big O Notation", fontsize = 28)
plt.legend(loc="upper right")

plt.xlabel('Elements')
plt.ylabel('Operations')

#hfont = {'fontname': 'Rockwell'}
hfont = {'fontname': 'Academy Engraved LET'}

plt.title('Veronica F. Reyes', loc='left', fontsize=20, **hfont)
# Out:
# Text(0.0, 1.0, 'Veronica F. Reyes')
